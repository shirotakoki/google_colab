# %%
import torch
from torch import FloatStorage, nn, optim

# %%
m = nn.Softmax(dim=2)
input = torch.randn(1, 2, 3)
output = m(input)
output
# Out:
# tensor([[[0.5305, 0.4318, 0.0377],
#          [0.0645, 0.5716, 0.3639]]])
